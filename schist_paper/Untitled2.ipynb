# %%
import schist
import scanpy as sc

# %%
adata = schist.io.read('iCELL8')

# %%
schist.__version__
# Out:
# '0.7.3+4.g5f083a2.dirty-py3.8.egg'

# %%
schist.inference.leiden(adata, get_marginals=True)

# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
adata.obs['mm'] = np.max(adata.obsm['CM_leiden'], axis=1)

# %%
sc.pl.umap(adata, color='mm')

# %%
schist.inference.planted_model(adata, n_init=10, random_seed=42)

# %%
sc.pl.umap(adata, color=['leiden', 'ppbm'])

# %%
schist.inference.planted_model(adata, n_init=100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-5d907024b2d2> in <module>
# ----> 1 schist.inference.planted_model(adata, n_init=100)
#
# ~/anaconda3/envs/experimental/lib/python3.8/site-packages/schist-0.7.3+4.g5f083a2.dirty-py3.8.egg/schist/inference/_planted_model.py in planted_model(adata, n_sweep, beta, tolerance, max_iterations, epsilon, equilibrate, wait, nbreaks, collect_marginals, niter_collect, deg_corr, n_init, beta_range, steps_anneal, resume, n_jobs, restrict_to, random_seed, key_added, adjacency, neighbors_key, directed, use_weights, copy, minimize_args, equilibrate_args)
#     232         # no list comprehension as I need to collect stats
#     233
# --> 234         states = Parallel(n_jobs=3, prefer='threads')(
#     235             delayed(fast_min)(state, beta, n_sweep, tolerance) for state in states
#     236         )
#
# ...

# %%
def fast_min(state, beta, n_sweep, fast_tol):
    dS = 1
    while np.abs(dS) > fast_tol:
        dS, natt, nm = state.multiflip_mcmc_sweep(beta=beta, niter=n_sweep)
    return state, dS, natt, nm
